# %% [markdown]
# ## use the twitter bag of words i.e #APPL and use it to learn the stock trends ( from yahoo and financial data). Based on the learnt model predict the stock trends from the twitter data using pandas, tensorflow

# %% [markdown]
# ### Collecting data from twitter api

# %%
import pandas as pd
import tweepy

# %%
consumer_key    = ''
consumer_secret = ''

access_token  = ''
access_token_secret = ''

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %% [markdown]
# ## Fetching tweets in extended mode(entire tweets not just a few words or link)

# %%
fetch_tweets=tweepy.Cursor(api.search, q="#AAPL",count=1000,since="2016-05-05",lang ="en", tweet_mode="extended").items()
data=pd.DataFrame(data=[[tweet_info.created_at.date(),tweet_info.full_text]for tweet_info in fetch_tweets],columns=['Date','Tweets'])

# %%
data
# Out:
#            Date                                             Tweets
# 0    2020-09-28  #NZDCAD Target Hit! 90 PIPS Profit 🔥\n\nFor Fo...
# 1    2020-09-28  #AAPL #AMZN Amazon Confirms Prime Day Coming O...
# 2    2020-09-28  1 hour chart for #AAPL $AAPL.  Next target pri...
# 3    2020-09-28  EURNZD TP2 Hit! 180 PIPS PROFIT 🔥👍🏻⚡️\n\nGet D...
# 4    2020-09-28  EURNZD TP2 Hit! 180 PIPS PROFIT 🔥👍🏻⚡️\n\nJoin ...
# 5    2020-09-28  Did a little adjustments in our signal bot and...
# 6    2020-09-28  Trade idea: APPLE INC. LONG: 📈 NASDAQ:AAPL LON...
# 7    2020-09-28  EURNZD TP2 Hit! 180 PIPS PROFIT 🔥👍🏻⚡️\n\nFor F...
# 8    2020-09-28  RT @pop_ey_ch: #AAPL 15min. While below 120.50...
# 9    2020-09-28  @OptionsMike @TopGunFP Something is rotten wit...
# 10   2020-09-28  If you #trade #stocks like #FB, #AAPL, #AMZN, ...
# 11   2020-09-28  #USDJPY TP2 Hit! 127 PIPS Profit🔥✨🔱\n\nFor fre...
# 12   2020-09-28  RT @BahosInvestmen1: Despite the possibility o...
# ...

# %% [markdown]
# ### after collecting data covert into csv format

# %%
data.to_csv('tweets.csv',index=False)

# %%
df=pd.read_csv('tweets.csv')

# %%
df.shape
# Out:
# (708, 2)

# %% [markdown]
# ####  sort the data by dates

# %%
df1=df.sort_values(by='Date')

# %%
df1
# Out:
#            Date                                             Tweets
# 707  2020-09-19  RT @AnkitMadX: Down % from Recent highs at yes...
# 675  2020-09-19  Makes sense why #AAPL stock is tanking. They h...
# 676  2020-09-19  Not AT&amp;T but it is Apple that needs to mak...
# 677  2020-09-19  @SPXTrades #AAPL Would love it at 99.33$ and a...
# 678  2020-09-19        sell  - #AAPL chart https://t.co/EJ84IJgndM
# 679  2020-09-19  🍏 $AAPL contact us to receive our entry and ex...
# 680  2020-09-19  RT @Ai2Stock: #StockMarket fell much in the la...
# 681  2020-09-19  #StockMarket fell much in the last 3 weeks(sin...
# 682  2020-09-19  #AAPL 1D/4H stochs. On 1D "could" be bullish w...
# 683  2020-09-19  #AAPL 1D/4H MACD. Have all ingredients to be s...
# 684  2020-09-19  Group 3 Stocks &amp; ETF charts are updated in...
# 685  2020-09-19  5 of the 254 semiconductor companies posted an...
# 686  2020-09-19  RT @matt801724: #GGP 2nd most purchased stock ...
# ...

# %% [markdown]
# ## collecting data from yahoo finance

# %%
import yfinance as yf

# %%
aapl_data=yf.Ticker("AAPL")

# %%
aapl_data.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
# ...

# %%
# get historical market data

# %%
aapl_data=aapl_data.history(start="2020-09-19",end="2020-09-28")

# %%
aapl_data.to_csv("AAPL_stock_data.csv")
